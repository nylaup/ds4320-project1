# %%
import pandas as pd
import requests

url = "https://data.cityofnewyork.us/api/v3/views/76xm-jjuj/query.json" 
APP_TOKEN = TOKEN
USERNAME = EMAIL
PASSWORD = PASS

batch_size = 50000

params = {
    "$query": """SELECT CAD_INCIDENT_ID, INCIDENT_DATETIME, BOROUGH 
    WHERE incident_datetime >= '2025-01-01'
    AND incident_datetime < '2026-01-01'
    LIMIT 50000 OFFSET {offset} """
}

headers = {"X-App-Token": APP_TOKEN}

r = requests.get(url, headers=headers, params=params, auth=(USERNAME, PASSWORD))
data = r.json()
print(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 20
#      11 params = {
#      12     "$query": """SELECT CAD_INCIDENT_ID, INCIDENT_DATETIME, BOROUGH
#      13     WHERE incident_datetime >= '2025-01-01'
#      14     AND incident_datetime < '2026-01-01'
#      15     LIMIT 50000 OFFSET {offset} """
#      16 }
#      18 headers = {"X-App-Token": APP_TOKEN}
# ---> 20 r = requests.get(url, headers=headers, params=params, auth=(USERNAME, PASSWORD))
#      21 data = r.json()
#      22 print(data)
#
# File ~/.local/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ...
